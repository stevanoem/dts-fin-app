# %%
import pandas as pd

# %%
file_path = r'..\inputs\ELIXIR ZORKA MINERALNA ĐUBRIVA DOO_14_08_2025_11_50 (1).xlsm'

# %%
all_data = {}

# %%
# LIST KUPAC

# %%
df1= pd.read_excel(file_path, engine='openpyxl', usecols='E:F', skiprows=4, header=None, nrows=12, sheet_name=0)
df1.columns= ['Atribut', 'Vrednost']

# %%
df1
# Out:
#                      Atribut  \
# 0                      Šifra
# 1                Naziv kupca
# 2            Datum osnivanja
# 3                        PIB
# 4           Vlasnici društva
# 5          Zastupnik društva
# 6   Poslovanje sa kupcem od:
# 7                      Mesto
# 8                         DC
# 9            Vrsta komitenta
# 10                    Valuta
# 11               Tolerancija
#
#                                              Vrednost
# 0                                             4093271
# 1                  ELIXIR ZORKA MINERALNA ĐUBRIVA DOO
# 2                                          25.08.2009
# 3                                           106257426
# 4                          ELIXIR GROUP DOO - 100,00%
# 5   Zorica Popović (54); Vladimir Petković (43); S...
# 6               Sa kupcem poslujemo duže od 3 godine.
# 7                                               Šabac
# 8                                                   -
# 9                                                   -
# 10                      Delta-plaćanje u roku 45 dana
# 11                                                  -

# %%
all_data["osnovne_informacije"] = df1.to_dict(orient='records')

# %%
df2= pd.read_excel(file_path, engine='openpyxl', usecols='E:F', skiprows=18, header=None, nrows=29, sheet_name=0)
df2.columns= ['Atribut', 'Vrednost RSD bez PDV']

# %%
df2 = df2.dropna()
df2
# Out:
#                                           Atribut  Vrednost RSD bez PDV
# 0                     Total promet za 2021.godinu          0.000000e+00
# 1                     Total promet za 2022.godinu          0.000000e+00
# 2                     Total promet za 2023.godinu          0.000000e+00
# 3                     Total promet za 2024.godinu          0.000000e+00
# 4                                 Promet 2022. Q1          0.000000e+00
# 5                                 Promet 2022. Q2          0.000000e+00
# 6                                 Promet 2022. Q3          0.000000e+00
# 7                                 Promet 2022. Q4          0.000000e+00
# 8                                 Promet 2023. Q1          0.000000e+00
# 9                                 Promet 2023. Q2          0.000000e+00
# 10                                Promet 2023. Q3          0.000000e+00
# 11                                Promet 2023. Q4          0.000000e+00
# 12                                Promet 2024. Q1          0.000000e+00
# 13                                Promet 2024. Q2          0.000000e+00
# 14                                Promet 2024. Q3          0.000000e+00
# 15                                Promet 2024. Q4          0.000000e+00
# 16                                Promet 2025. Q1          0.000000e+00
# 17                                Promet 2025. Q2          0.000000e+00
# 18                                Promet 2025. Q3          0.000000e+00
# 19                                Promet 2025. Q4          0.000000e+00
# 21                       Planirani mesečni promet          0.000000e+00
# 23                Promet u poslednja tri kvartala          0.000000e+00
# 25                      Dug na dan obrade zahteva          1.503484e+06
# 26              Dospelo na dan podnosenja zahteva          4.899136e+05
# 28  Prosečan broj dana kašnjenja u poslednjih 12m         -1.925941e+00

# %%
df2 = df2.tail(3)
df2
# Out:
#                                           Atribut  Vrednost RSD bez PDV
# 25                      Dug na dan obrade zahteva          1.503484e+06
# 26              Dospelo na dan podnosenja zahteva          4.899136e+05
# 28  Prosečan broj dana kašnjenja u poslednjih 12m         -1.925941e+00

# %%
all_data["prometRSD"] = df2.to_dict(orient='records')

# %%
df3= pd.read_excel(file_path, engine='openpyxl', usecols='I:J', skiprows=9, header=None, nrows=10, sheet_name=0)
df3.columns= ['Atribut', 'Vrednost']

# %%
df3
# Out:
#                                              Atribut                 Vrednost
# 0  NBS blokada- iznos i datum poslednje zabeležen...                     Nema
# 1                                      Rizična lica                      Nema
# 2                           Period poslednje blokade                        -
# 3                                        Broj menica                PROVERITI
# 4                                        Povlašenost  Povlasceni - bez menica
# 5                                                PPL                      Ima
# 6                                     Status PPL-ova                  Aktivan
# 7                       Sporovi u poslednje 3 godine                      Ima
# 8                          Osoba odgovorna za kupca:        Sara Kurbatfinski
# 9               Puštene blanko menice od 2018.godine                      NaN

# %%
all_data["ocena_rizika"] = df3.to_dict(orient='records')

# %%
# EUR
df4= pd.read_excel(file_path, engine='openpyxl', usecols='I:N', skiprows=26, header=0, nrows=21, sheet_name=0)
df4 = df4.rename(columns={'Unnamed: 8': 'Atribut'})

# %%
df4
# Out:
#                                               Atribut        2022        2023  \
# 0                                         APR Kapital   106180354   107715417
# 1                                     Ukupni prihodi    346673550   260149692
# 2                             Prihodi od prodaje robe    94559973    86090257
# 3                                              EBITDA    66459695    23562907
# 4               Neto radni kapital (Neto obrtni fond)    69617217    67386393
# 5                                            Gotovina     5386413    10072823
# 6                              Potraživanja od kupaca    79473493    78062201
# 7                                              Zalihe   137093358    40633666
# 8                          Obaveze prema dobavljačima    39343168    28707696
# 9                                      Obrtna imovina   157536591   137325756
# 10                                Kratkoročne obaveze    87919374    69939363
# 11                   WC (CASH+ZALIHE+POTR-DOBAVLJACI)   182610096   100060994
# 12                           Racio tekuće likvidnosti     1.79183    1.963497
# 13                        Racio redukovane likvdnosti    1.012176    1.382513
# 14    Prosečno vreme plaćanja dobavljačima (u danima)   46.800769   55.005043
# 15                          Učešće u kupčevom prometu           -           -
# 16  Net Worth= (customer’s total assets-total liab...  10618035.4  10771541.7
# 17             10% of the customer’s working capital   18261009.6  10006099.4
# 18               Preracn na osnovu ostvarenog prometa           -           -
# 19                                  Kombinovani u EUR           -           -
# 20                                    Broj zaposlenih         400         413
#
#          2024 2023/2022 % 2024/2023 %
# 0    92453849    0.014457   -0.141684
# 1   238119427   -0.249583   -0.084683
# 2    58012817    -0.08957    -0.32614
# 3    14253911   -0.645456    -0.39507
# 4    51225425   -0.032044   -0.239825
# 5     4969426    0.870043    -0.50665
# 6    38137997   -0.017758   -0.511441
# 7    41270846   -0.703606    0.015681
# 8    26840769   -0.270326   -0.065032
# 9   103190636   -0.128293    -0.24857
# 10   51965211   -0.204506   -0.256996
# 11   57537500   -0.452051   -0.424976
# 12   1.985764    0.095805     0.01134
# 13   1.191562    0.365882   -0.138119
# 14   48.37704    0.175302   -0.120498
# 15          -           -           -
# 16  9245384.9    0.014457   -0.141684
# 17    5753750   -0.452051   -0.424976
# 18          -           -           -
# 19          -           -           -
# 20        412      0.0325   -0.002421

# %%
all_data["finansijska_analizaEUR"] = df4.to_dict(orient='records')

# %%
df5= pd.read_excel(file_path, engine='openpyxl', usecols='E:F', skiprows=50, header=None, nrows=6, sheet_name=0)
df5.columns = ['Atribut', 'Vrednost RSD']

# %%
df5
# Out:
#                                              Atribut  \
# 0  Predlog kredit limita na osnovu ostvarenog pro...
# 1  Predlog kredit limita na osnovu prometa u pret...
# 2                         Kombinovani kreditni limit
# 3                      Postojeća visina kredit limta
# 4                    Tražena korekcija kredit limita
# 5            Obrazloženje za podizanje kredit limita
#
#                                         Vrednost RSD
# 0                                                  -
# 1                                                  -
# 2                                                  -
# 3                                            2000000
# 4                                            2500000
# 5  2x naloga po 950e zavrsena i imamo jos dva pot...

# %%
all_data["predlogRSD"] = df5.to_dict(orient='records')

# %%
#Tabela 6: Bonitetna ocena
df6_1 = pd.read_excel(file_path, sheet_name=0, usecols="L:O", skiprows=7, nrows=1, header=1, engine='openpyxl')
prefix = df6_1.columns[0]
df6_1 = df6_1.drop(columns=[prefix])
df6_1.columns = [f"{prefix} {col}" for col in df6_1.columns]

df6_2 = pd.read_excel(file_path, sheet_name=0, usecols="L:M", skiprows=10, nrows=1, header=None, engine='openpyxl')
col_name = df6_2.iloc[0,0]
value = df6_2.iloc[0,1]
df6_2= pd.DataFrame({col_name: [value]})

df6 = pd.concat([df6_1, df6_2], axis=1)

# %%
df6
# Out:
#                                 Bonitetna ocena 2024 Bonitetna ocena 2023  \
# 0  C1 - Preduzeće posluje prosečno i ima povećanu...                   B2
#
#   Bonitetna ocena 2022                                       Ocena rizika
# 0                   B2  Ukupna ocena rizičnosti preduzeća je 36, što u...

# %%
all_data["bonitetna_ocena"] = df6.to_dict(orient='records')

# %%
#Tabela 7: Istorija izmene KL
df7 = pd.read_excel(
      file_path,
      sheet_name=0,
      usecols="I:K",
      skiprows=52,
      header=0,
      engine='openpyxl'
)
if df7.dropna(how='all').empty:
    print("Tabela kreditne istorije je prazna.")
    df7 = df7.dropna(how='all')
# Out:
# Tabela kreditne istorije je prazna.

# %%
all_data["istorijaKL"] = df7.to_dict(orient='records')

# %%
# LIST SUDSKI SPOROVI
sheet_name_sporovi = 2
try:
    df9 = pd.read_excel(file_path, sheet_name=sheet_name_sporovi, engine='openpyxl')
    all_data["sudski sporovi"] = df9.to_dict(orient='records')
    if df9.empty:
        print("Tabela sudskih sporova je prazna.")
except Exception as e:
    print(f"Nije moguće pročitati list '{sheet_name_sporovi}': {e}. Preskačem.")
    all_data["sudski sporovi"] = []
# Out:
# Tabela sudskih sporova je prazna.

# %%
#LIST REZIME
sheet_name_rezime = 4
try:
    df8 = pd.read_excel(file_path, sheet_name=sheet_name_rezime, usecols="B:G", skiprows=3, nrows=30, header=0, engine='openpyxl')
    all_data["rezimeEUR"] = df8.to_dict(orient='records')
except Exception as e:
    print(f"Nije moguće pročitati list '{sheet_name_rezime}': {e}. Preskačem.")
    all_data["rezimeEUR"] = []

# %%
df8
# Out:
#                                                 Naziv          2020  \
# 0                           SAŽETAK - Broj zaposlenih  3.970000e+02
# 1                                        NETO DOBITAK  2.349200e+05
# 2                                       SAŽETAK - EBT  1.405814e+06
# 3                                    SAŽETAK - Ebitda  5.445159e+06
# 4                   Gotovina i gotovinski ekvivalenti  7.032459e+06
# 5     SAŽETAK - Neto radni kapital (neto obrtni fond)  5.661230e+07
# 6                SAŽETAK - Obaveze prema dobavljačima  2.453126e+07
# 7                              Poreski rashod perioda  4.266000e+04
# 8                     SAŽETAK - Potraživanja od kupca  5.417824e+07
# 9                             SAŽETAK - Produktivnost  2.896719e+00
# 10                           SAŽETAK - Ukupni prihodi  1.591342e+08
# 11                                 Veličina preduzeća  0.000000e+00
# 12                                     OBRTNA IMOVINA  9.793347e+07
# 13                                             ZALIHE  3.583187e+07
# 14                                      UKUPNA PASIVA  1.566858e+08
# 15                                            Kapital  7.646704e+07
# 16                                    Osnovni kapital  1.823730e+07
# 17         DUGOROČNA REZERVISANJA I DUGOROČNE OBAVEZE  3.889756e+07
# 18                                  Dugoročne obaveze  3.857143e+07
# 19     KRATKOROČNA REZERVISANJA I KRATKOROČNE OBAVEZE  4.132117e+07
# 20                              Obaveze iz poslovanja  2.453126e+07
# 21                         Ostale kratkoročne obaveze  4.750451e+06
# 22                            Prihodi od prodaje robe  4.784061e+07
# 23                              Troškovi amortizacije  2.594918e+06
# 24  LIKVIDNOST - Koeficijent tekuće likvidnosti (o...  2.370056e+00
# 25  LIKVIDNOST - Koeficijent ubrzane likvidnosti (...  1.502900e+00
# 26          AKTIVNOST - Vreme obrta zaliha (u danima)  1.001861e+02
# 27  AKTIVNOST - Prosečno vreme plaćanja dobavljači...  7.013576e+01
# 28  Stalna imovina koja se drži za prodaju i prest...  0.000000e+00
#
#             2021          2022          2023          2024
# 0   4.130000e+02  4.000000e+02  4.130000e+02  4.120000e+02
# 1   1.185841e+07  5.570411e+07  1.401357e+07  4.753215e+06
# 2   1.374708e+07  5.796480e+07  1.354714e+07  5.877430e+06
# 3   2.188299e+07  6.645970e+07  2.356291e+07  1.425391e+07
# 4   7.761206e+06  5.386413e+06  1.007282e+07  4.969426e+06
# 5   4.684385e+07  6.961722e+07  6.738639e+07  5.122542e+07
# 6   2.849201e+07  3.934317e+07  2.870770e+07  2.684077e+07
# 7   4.186940e+05  1.004914e+06  2.428010e+05  1.167697e+06
# 8   4.849424e+07  7.947349e+07  7.806220e+07  3.813800e+07
# 9   2.591155e+00  4.985448e+00  3.496544e+00  2.948215e+00
# 10  1.647200e+08  3.466736e+08  2.601497e+08  2.381194e+08
# 11  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 12  8.953069e+07  1.575366e+08  1.373258e+08  1.031906e+08
# 13  6.194206e+07  1.370934e+08  4.063367e+07  4.127085e+07
# 14  1.578544e+08  2.259805e+08  2.165583e+08  1.813440e+08
# 15  8.032636e+07  1.061804e+08  1.077154e+08  9.245385e+07
# 16  3.647402e+07  3.655476e+07  3.660115e+07  1.832541e+07
# 17  3.412925e+07  2.991143e+07  3.631491e+07  3.429171e+07
# 18  3.255671e+07  2.696897e+07  3.391183e+07  3.212348e+07
# 19  4.268685e+07  8.791937e+07  6.993936e+07  5.196521e+07
# 20  2.849201e+07  3.934317e+07  2.870770e+07  2.684077e+07
# 21  9.235750e+05  2.480131e+06  8.608240e+05  4.927570e+05
# 22  5.220185e+07  9.455997e+07  8.609026e+07  5.801282e+07
# 23  3.560456e+06  4.386110e+06  4.417236e+06  5.413045e+06
# 24  2.097384e+00  1.791830e+00  1.963497e+00  1.985764e+00
# 25  1.371843e+00  1.012176e+00  1.382513e+00  1.191562e+00
# 26  9.187540e+01  1.021315e+02  7.547102e+01  8.581248e+01
# 27  7.106900e+01  4.680077e+01  5.500504e+01  4.837704e+01
# 28  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00

# %%
# LIST POVEZANA LICA
sheet_name_rezime = 1
try:
    df10 = pd.read_excel(file_path, sheet_name=sheet_name_rezime, usecols="A:D",  header=0, engine='openpyxl')
    all_data["povezana_lica"] = df10.to_dict(orient='records')
except Exception as e:
    print(f"Nije moguće pročitati list '{sheet_name_rezime}': {e}. Preskačem.")
    all_data["povezana_lica"] = []

# %%
df10
# Out:
#                                   Naziv preduzeća Oblik povezanosti  \
# 0                                ELIXIR GROUP DOO             Majka
# 1                          ELIXIR ENGINEERING DOO            Sestra
# 2                       ELIXIR FEED ADDITIVES DOO            Sestra
# 3                              ELIXIR PRAHOVO DOO            Sestra
# 4                   METAL RECOVERY D.O.O. BEOGRAD            Sestra
# 5                                ELIXIR CRAFT DOO            Sestra
# 6                       ELIXIR GARDEN NEGOTIN DOO            Sestra
# 7   CENTAR ZA PRIMENJENU CIRKULARNU EKONOMIJU DOO            Sestra
# 8                                     ST MEDICINA            Sestra
# 9                           ELIXIR FOSFATI CG DOO            Sestra
# 10           LOGISTIKA I TRANSPORT HEMIKALIJA DOO            Sestra
# 11                                X PLUS 2024 DOO            Sestra
# 12             STEFAN KOMAZEC PR PROORG SOLUTIONS        Menadžment
# 13                        DIJAMANT NEKRETNINE DOO        Menadžment
# 14                                          BP-SG        Menadžment
# 15                             GARDEN SP 2019 DOO        Menadžment
# 16                               ELIXIR FONDACIJA        Menadžment
# 17                           RENTA SPACE 2023 DOO        Menadžment
# 18                 STAMBENA ZAJEDNICA IZVORSKA 44        Menadžment
# 19                   SEA DANUBE TRANS DOO BEOGRAD        Menadžment
# 20                                TOCCA BOCCA DOO        Menadžment
#
#    APR Status NBS Status
# 0     Aktivan    Aktivan
# 1     Aktivan    Aktivan
# 2     Aktivan    Aktivan
# 3     Aktivan    Aktivan
# 4     Aktivan    Aktivan
# 5     Aktivan    Aktivan
# 6     Aktivan    Aktivan
# 7     Aktivan    Aktivan
# 8     Aktivan    Aktivan
# 9     Aktivan    Aktivan
# 10    Aktivan    Aktivan
# 11    Aktivan    Aktivan
# 12    Aktivan    Aktivan
# 13    Aktivan    Aktivan
# 14    Aktivan    Aktivan
# 15    Aktivan    Aktivan
# 16    Aktivan    Aktivan
# 17    Aktivan    Aktivan
# 18          -          -
# 19    Aktivan    Aktivan
# 20    Aktivan    Aktivan

# %%
all_data
# Out:
# {'osnovne_informacije': [{'Atribut': 'Šifra', 'Vrednost': 4093271},
#   {'Atribut': 'Naziv kupca', 'Vrednost': 'ELIXIR ZORKA MINERALNA ĐUBRIVA DOO'},
#   {'Atribut': 'Datum osnivanja', 'Vrednost': '25.08.2009'},
#   {'Atribut': 'PIB', 'Vrednost': 106257426},
#   {'Atribut': 'Vlasnici društva', 'Vrednost': 'ELIXIR GROUP DOO - 100,00%'},
#   {'Atribut': 'Zastupnik društva',
#    'Vrednost': 'Zorica Popović (54); Vladimir Petković (43); Samir Krak (55); Vladimir Todorović (65); Nebojša Mićić (57)'},
#   {'Atribut': 'Poslovanje sa kupcem od:',
#    'Vrednost': 'Sa kupcem poslujemo duže od 3 godine.'},
#   {'Atribut': 'Mesto', 'Vrednost': 'Šabac'},
#   {'Atribut': 'DC', 'Vrednost': '-'},
#   {'Atribut': 'Vrsta komitenta', 'Vrednost': '-'},
#   {'Atribut': 'Valuta', 'Vrednost': 'Delta-plaćanje u roku 45 dana'},
#   {'Atribut': 'Tolerancija', 'Vrednost': '-'}],
#  'prometRSD': [{'Atribut': 'Dug na dan obrade zahteva',
#    'Vrednost RSD bez PDV': 1503483.62},
#   {'Atribut': 'Dospelo na dan podnosenja zahteva',
#    'Vrednost RSD bez PDV': 489913.61},
#   {'Atribut': 'Prosečan broj dana kašnjenja u poslednjih 12m',
#    'Vrednost RSD bez PDV': -1.9259405175635542}],
#  'ocena_rizika': [{'Atribut': 'NBS blokada- iznos i datum poslednje zabeležene blokade',
#    'Vrednost': 'Nema'},
#   {'Atribut': 'Rizična lica ', 'Vrednost': 'Nema'},
#   {'Atribut': 'Period poslednje blokade', 'Vrednost': '-'},
#   {'Atribut': 'Broj menica', 'Vrednost': 'PROVERITI'},
#   {'Atribut': 'Povlašenost', 'Vrednost': 'Povlasceni - bez menica'},
#   {'Atribut': 'PPL', 'Vrednost': 'Ima'},
#   {'Atribut': 'Status PPL-ova', 'Vrednost': 'Aktivan'},
#   {'Atribut': 'Sporovi u poslednje 3 godine', 'Vrednost': 'Ima'},
#   {'Atribut': 'Osoba odgovorna za kupca:', 'Vrednost': 'Sara Kurbatfinski'},
#   {'Atribut': 'Puštene blanko menice od 2018.godine', 'Vrednost': nan}],
#  'finansijska_analizaEUR': [{'Atribut': 'APR Kapital',
#    2022: 106180354,
#    2023: 107715417,
#    2024: 92453849,
#    '2023/2022 %': 0.014457128293243304,
#    '2024/2023 %': -0.14168415650287092},
#   {'Atribut': 'Ukupni prihodi ',
#    2022: 346673550,
#    2023: 260149692,
#    2024: 238119427,
#    '2023/2022 %': -0.24958309625871367,
#    '2024/2023 %': -0.08468303318229564},
#   {'Atribut': 'Prihodi od prodaje robe',
#    2022: 94559973,
#    2023: 86090257,
#    2024: 58012817,
#    '2023/2022 %': -0.0895697802282579,
#    '2024/2023 %': -0.3261395769790767},
#   {'Atribut': 'EBITDA',
#    2022: 66459695,
#    2023: 23562907,
#    2024: 14253911,
#    '2023/2022 %': -0.6454556855850753,
#    '2024/2023 %': -0.3950699291899764},
#   {'Atribut': 'Neto radni kapital (Neto obrtni fond)',
#    2022: 69617217,
#    2023: 67386393,
#    2024: 51225425,
#    '2023/2022 %': -0.032044142183965785,
#    '2024/2023 %': -0.23982539026832905},
#   {'Atribut': 'Gotovina',
#    2022: 5386413,
#    2023: 10072823,
#    2024: 4969426,
#    '2023/2022 %': 0.870042828130706,
#    '2024/2023 %': -0.5066501218178856},
#   {'Atribut': 'Potraživanja od kupaca',
#    2022: 79473493,
#    2023: 78062201,
#    2024: 38137997,
#    '2023/2022 %': -0.01775802153304118,
#    '2024/2023 %': -0.5114409213237531},
#   {'Atribut': 'Zalihe',
#    2022: 137093358,
#    2023: 40633666,
#    2024: 41270846,
#    '2023/2022 %': -0.7036058741810088,
#    '2024/2023 %': 0.01568108572827276},
#   {'Atribut': 'Obaveze prema dobavljačima',
#    2022: 39343168,
#    2023: 28707696,
#    2024: 26840769,
#    '2023/2022 %': -0.27032576532728625,
#    '2024/2023 %': -0.06503228263250382},
#   {'Atribut': 'Obrtna imovina',
#    2022: 157536591,
#    2023: 137325756,
#    2024: 103190636,
#    '2023/2022 %': -0.12829295639639682,
#    '2024/2023 %': -0.24857041384137724},
#   {'Atribut': 'Kratkoročne obaveze',
#    2022: 87919374,
#    2023: 69939363,
#    2024: 51965211,
#    '2023/2022 %': -0.20450567584796497,
#    '2024/2023 %': -0.25699622114087595},
#   {'Atribut': 'WC (CASH+ZALIHE+POTR-DOBAVLJACI)',
#    2022: 182610096,
#    2023: 100060994,
#    2024: 57537500,
#    '2023/2022 %': -0.45205113960402277,
#    '2024/2023 %': -0.4249757303030589},
#   {'Atribut': 'Racio tekuće likvidnosti',
#    2022: 1.79183021629268,
#    2023: 1.96349737292762,
#    2024: 1.98576381945248,
#    '2023/2022 %': 0.09580548149819768,
#    '2024/2023 %': 0.011340196748855558},
#   {'Atribut': 'Racio redukovane likvdnosti',
#    2022: 1.01217635206195,
#    2023: 1.38251315976685,
#    2024: 1.19156235856901,
#    '2023/2022 %': 0.3658817032728243,
#    '2024/2023 %': -0.13811861380765622},
#   {'Atribut': 'Prosečno vreme plaćanja dobavljačima (u danima)',
#    2022: 46.8007687142826,
#    2023: 55.0050431704379,
#    2024: 48.3770396478198,
#    '2023/2022 %': 0.17530213031846054,
#    '2024/2023 %': -0.12049810600240163},
#   {'Atribut': 'Učešće u kupčevom prometu',
#    2022: '-',
#    2023: '-',
#    2024: '-',
#    '2023/2022 %': '-',
#    '2024/2023 %': '-'},
#   {'Atribut': 'Net Worth= (customer’s total assets-total liabilities) / 10',
#    2022: 10618035.4,
#    2023: 10771541.7,
#    2024: 9245384.9,
#    '2023/2022 %': 0.014457128293243304,
#    '2024/2023 %': -0.1416841565028708},
#   {'Atribut': '10% of the customer’s working capital\xa0',
#    2022: 18261009.6,
#    2023: 10006099.4,
#    2024: 5753750,
#    '2023/2022 %': -0.45205113960402277,
#    '2024/2023 %': -0.424975730303059},
#   {'Atribut': 'Preracn na osnovu ostvarenog prometa',
#    2022: '-',
#    2023: '-',
#    2024: '-',
#    '2023/2022 %': '-',
#    '2024/2023 %': '-'},
#   {'Atribut': 'Kombinovani u EUR',
#    2022: '-',
#    2023: '-',
#    2024: '-',
#    '2023/2022 %': '-',
#    '2024/2023 %': '-'},
#   {'Atribut': 'Broj zaposlenih',
#    2022: 400,
#    2023: 413,
#    2024: 412,
#    '2023/2022 %': 0.03249999999999997,
#    '2024/2023 %': -0.002421307506053294}],
#  'predlogRSD': [{'Atribut': 'Predlog kredit limita na osnovu ostvarenog prometa u Q4 2023.',
#    'Vrednost RSD': '-'},
#   {'Atribut': 'Predlog kredit limita na osnovu prometa u prethodna tri kvartala',
#    'Vrednost RSD': '-'},
#   {'Atribut': 'Kombinovani kreditni limit', 'Vrednost RSD': '-'},
#   {'Atribut': 'Postojeća visina kredit limta', 'Vrednost RSD': 2000000},
#   {'Atribut': 'Tražena korekcija kredit limita', 'Vrednost RSD': 2500000},
#   {'Atribut': 'Obrazloženje za podizanje kredit limita',
#    'Vrednost RSD': '2x naloga po 950e zavrsena i imamo jos dva potvrdjena za pocetak nedelje '}],
#  'bonitetna_ocena': [{'Bonitetna ocena 2024': 'C1 - Preduzeće posluje prosečno i ima povećanu verovatnoću neuspeha u budućnosti.',
#    'Bonitetna ocena 2023': 'B2',
#    'Bonitetna ocena 2022': 'B2',
#    'Ocena rizika': 'Ukupna ocena rizičnosti preduzeća je 36, što ukazuje na umeren nivo rizika'}],
#  'istorijaKL': [],
#  'sudski sporovi': [],
#  'rezimeEUR': [{'Naziv': 'SAŽETAK - Broj zaposlenih',
#    2020: 397.0,
#    2021: 413.0,
#    2022: 400.0,
#    2023: 413.0,
#    2024: 412.0},
#   {'Naziv': 'NETO DOBITAK',
#    2020: 234920.0,
#    2021: 11858412.0,
#    2022: 55704111.0,
#    2023: 14013571.0,
#    2024: 4753215.0},
#   {'Naziv': 'SAŽETAK - EBT',
#    2020: 1405814.0,
#    2021: 13747083.0,
#    2022: 57964796.0,
#    2023: 13547144.0,
#    2024: 5877430.0},
#   {'Naziv': 'SAŽETAK - Ebitda',
#    2020: 5445159.0,
#    2021: 21882990.0,
#    2022: 66459695.0,
#    2023: 23562907.0,
#    2024: 14253911.0},
#   {'Naziv': 'Gotovina i gotovinski ekvivalenti',
#    2020: 7032459.0,
#    2021: 7761206.0,
#    2022: 5386413.0,
#    2023: 10072823.0,
#    2024: 4969426.0},
#   {'Naziv': 'SAŽETAK - Neto radni kapital (neto obrtni fond)',
#    2020: 56612303.0,
#    2021: 46843847.0,
#    2022: 69617217.0,
#    2023: 67386393.0,
#    2024: 51225425.0},
#   {'Naziv': 'SAŽETAK - Obaveze prema dobavljačima',
#    2020: 24531256.0,
#    2021: 28492006.0,
#    2022: 39343168.0,
#    2023: 28707696.0,
#    2024: 26840769.0},
#   {'Naziv': 'Poreski rashod perioda',
#    2020: 42660.0,
#    2021: 418694.0,
#    2022: 1004914.0,
#    2023: 242801.0,
#    2024: 1167697.0},
#   {'Naziv': 'SAŽETAK - Potraživanja od kupca',
#    2020: 54178245.0,
#    2021: 48494235.0,
#    2022: 79473493.0,
#    2023: 78062201.0,
#    2024: 38137997.0},
#   {'Naziv': 'SAŽETAK - Produktivnost',
#    2020: 2.89671943948651,
#    2021: 2.59115541093769,
#    2022: 4.98544820227979,
#    2023: 3.49654446669366,
#    2024: 2.94821526349743},
#   {'Naziv': 'SAŽETAK - Ukupni prihodi',
#    2020: 159134216.0,
#    2021: 164720029.0,
#    2022: 346673550.0,
#    2023: 260149692.0,
#    2024: 238119427.0},
#   {'Naziv': 'Veličina preduzeća',
#    2020: 0.0,
#    2021: 0.0,
#    2022: 0.0,
#    2023: 0.0,
#    2024: 0.0},
#   {'Naziv': 'OBRTNA IMOVINA',
#    2020: 97933470.0,
#    2021: 89530693.0,
#    2022: 157536591.0,
#    2023: 137325756.0,
#    2024: 103190636.0},
#   {'Naziv': 'ZALIHE',
#    2020: 35831874.0,
#    2021: 61942064.0,
#    2022: 137093358.0,
#    2023: 40633666.0,
#    2024: 41270846.0},
#   {'Naziv': 'UKUPNA PASIVA',
#    2020: 156685768.0,
#    2021: 157854435.0,
#    2022: 225980486.0,
#    2023: 216558280.0,
#    2024: 181344025.0},
#   {'Naziv': 'Kapital',
#    2020: 76467041.0,
#    2021: 80326359.0,
#    2022: 106180354.0,
#    2023: 107715417.0,
#    2024: 92453849.0},
#   {'Naziv': 'Osnovni kapital',
#    2020: 18237305.0,
#    2021: 36474020.0,
#    2022: 36554758.0,
#    2023: 36601148.0,
#    2024: 18325409.0},
#   {'Naziv': 'DUGOROČNA REZERVISANJA I DUGOROČNE OBAVEZE',
#    2020: 38897560.0,
#    2021: 34129250.0,
#    2022: 29911432.0,
#    2023: 36314906.0,
#    2024: 34291709.0},
#   {'Naziv': 'Dugoročne obaveze',
#    2020: 38571426.0,
#    2021: 32556707.0,
#    2022: 26968967.0,
#    2023: 33911833.0,
#    2024: 32123481.0},
#   {'Naziv': 'KRATKOROČNA REZERVISANJA I KRATKOROČNE OBAVEZE',
#    2020: 41321166.0,
#    2021: 42686846.0,
#    2022: 87919374.0,
#    2023: 69939363.0,
#    2024: 51965211.0},
#   {'Naziv': 'Obaveze iz poslovanja',
#    2020: 24531256.0,
#    2021: 28492006.0,
#    2022: 39343168.0,
#    2023: 28707696.0,
#    2024: 26840769.0},
#   {'Naziv': 'Ostale kratkoročne obaveze',
#    2020: 4750451.0,
#    2021: 923575.0,
#    2022: 2480131.0,
#    2023: 860824.0,
#    2024: 492757.0},
#   {'Naziv': 'Prihodi od prodaje robe',
#    2020: 47840614.0,
#    2021: 52201848.0,
#    2022: 94559973.0,
#    2023: 86090257.0,
#    2024: 58012817.0},
#   {'Naziv': 'Troškovi amortizacije',
#    2020: 2594918.0,
#    2021: 3560456.0,
#    2022: 4386110.0,
#    2023: 4417236.0,
#    2024: 5413045.0},
#   {'Naziv': 'LIKVIDNOST - Koeficijent tekuće likvidnosti (opšti racio likvidnosti)',
#    2020: 2.37005580470391,
#    2021: 2.09738367141117,
#    2022: 1.79183021629268,
#    2023: 1.96349737292762,
#    2024: 1.98576381945248},
#   {'Naziv': 'LIKVIDNOST - Koeficijent ubrzane likvidnosti (rigorozni racio likvidnosti)',
#    2020: 1.50290035033079,
#    2021: 1.37184325259219,
#    2022: 1.01217635206195,
#    2023: 1.38251315976685,
#    2024: 1.19156235856901},
#   {'Naziv': 'AKTIVNOST - Vreme obrta zaliha (u danima)',
#    2020: 100.186147431233,
#    2021: 91.8753986980799,
#    2022: 102.13148987299,
#    2023: 75.4710228998749,
#    2024: 85.812484759328},
#   {'Naziv': 'AKTIVNOST - Prosečno vreme plaćanja dobavljačima (u danima)',
#    2020: 70.1357599479177,
#    2021: 71.0690011138773,
#    2022: 46.8007687142826,
#    2023: 55.0050431704379,
#    2024: 48.3770396478198},
#   {'Naziv': 'Stalna imovina koja se drži za prodaju i prestanak poslovanja',
#    2020: 0.0,
#    2021: 0.0,
#    2022: 0.0,
#    2023: 0.0,
#    2024: 0.0}],
#  'povezana_lica': [{'Naziv preduzeća': 'ELIXIR GROUP DOO',
#    'Oblik povezanosti': 'Majka',
#    'APR Status': 'Aktivan',
#    'NBS Status': 'Aktivan'},
#   {'Naziv preduzeća': 'ELIXIR ENGINEERING DOO',
#    'Oblik povezanosti': 'Sestra',
#    'APR Status': 'Aktivan',
#    'NBS Status': 'Aktivan'},
#   {'Naziv preduzeća': 'ELIXIR FEED ADDITIVES DOO',
#    'Oblik povezanosti': 'Sestra',
#    'APR Status': 'Aktivan',
#    'NBS Status': 'Aktivan'},
#   {'Naziv preduzeća': 'ELIXIR PRAHOVO DOO',
#    'Oblik povezanosti': 'Sestra',
#    'APR Status': 'Aktivan',
#    'NBS Status': 'Aktivan'},
#   {'Naziv preduzeća': 'METAL RECOVERY D.O.O. BEOGRAD',
#    'Oblik povezanosti': 'Sestra',
#    'APR Status': 'Aktivan',
#    'NBS Status': 'Aktivan'},
#   {'Naziv preduzeća': 'ELIXIR CRAFT DOO',
#    'Oblik povezanosti': 'Sestra',
#    'APR Status': 'Aktivan',
#    'NBS Status': 'Aktivan'},
#   {'Naziv preduzeća': 'ELIXIR GARDEN NEGOTIN DOO',
#    'Oblik povezanosti': 'Sestra',
#    'APR Status': 'Aktivan',
#    'NBS Status': 'Aktivan'},
#   {'Naziv preduzeća': 'CENTAR ZA PRIMENJENU CIRKULARNU EKONOMIJU DOO',
#    'Oblik povezanosti': 'Sestra',
#    'APR Status': 'Aktivan',
#    'NBS Status': 'Aktivan'},
#   {'Naziv preduzeća': 'ST MEDICINA',
#    'Oblik povezanosti': 'Sestra',
#    'APR Status': 'Aktivan',
#    'NBS Status': 'Aktivan'},
#   {'Naziv preduzeća': 'ELIXIR FOSFATI CG DOO',
#    'Oblik povezanosti': 'Sestra',
#    'APR Status': 'Aktivan',
#    'NBS Status': 'Aktivan'},
#   {'Naziv preduzeća': 'LOGISTIKA I TRANSPORT HEMIKALIJA DOO',
#    'Oblik povezanosti': 'Sestra',
#    'APR Status': 'Aktivan',
#    'NBS Status': 'Aktivan'},
#   {'Naziv preduzeća': 'X PLUS 2024 DOO',
#    'Oblik povezanosti': 'Sestra',
#    'APR Status': 'Aktivan',
#    'NBS Status': 'Aktivan'},
#   {'Naziv preduzeća': 'STEFAN KOMAZEC PR PROORG SOLUTIONS',
#    'Oblik povezanosti': 'Menadžment',
#    'APR Status': 'Aktivan',
#    'NBS Status': 'Aktivan'},
#   {'Naziv preduzeća': 'DIJAMANT NEKRETNINE DOO',
#    'Oblik povezanosti': 'Menadžment',
#    'APR Status': 'Aktivan',
#    'NBS Status': 'Aktivan'},
#   {'Naziv preduzeća': 'BP-SG',
#    'Oblik povezanosti': 'Menadžment',
#    'APR Status': 'Aktivan',
#    'NBS Status': 'Aktivan'},
#   {'Naziv preduzeća': 'GARDEN SP 2019 DOO',
#    'Oblik povezanosti': 'Menadžment',
#    'APR Status': 'Aktivan',
#    'NBS Status': 'Aktivan'},
#   {'Naziv preduzeća': 'ELIXIR FONDACIJA',
#    'Oblik povezanosti': 'Menadžment',
#    'APR Status': 'Aktivan',
#    'NBS Status': 'Aktivan'},
#   {'Naziv preduzeća': 'RENTA SPACE 2023 DOO',
#    'Oblik povezanosti': 'Menadžment',
#    'APR Status': 'Aktivan',
#    'NBS Status': 'Aktivan'},
#   {'Naziv preduzeća': 'STAMBENA ZAJEDNICA IZVORSKA 44',
#    'Oblik povezanosti': 'Menadžment',
#    'APR Status': '-',
#    'NBS Status': '-'},
#   {'Naziv preduzeća': 'SEA DANUBE TRANS DOO BEOGRAD',
#    'Oblik povezanosti': 'Menadžment',
#    'APR Status': 'Aktivan',
#    'NBS Status': 'Aktivan'},
#   {'Naziv preduzeća': 'TOCCA BOCCA DOO',
#    'Oblik povezanosti': 'Menadžment',
#    'APR Status': 'Aktivan',
#    'NBS Status': 'Aktivan'}]}
